# %% [markdown]
# <!--BOOK_INFORMATION-->
# <img align="left" style="padding-right:10px;" src="figures/PDSH-cover-small.png">
# *This notebook contains an excerpt from the [Python Data Science Handbook](http://shop.oreilly.com/product/0636920034919.do) by Jake VanderPlas; the content is available [on GitHub](https://github.com/jakevdp/PythonDataScienceHandbook).*
#
# *The text is released under the [CC-BY-NC-ND license](https://creativecommons.org/licenses/by-nc-nd/3.0/us/legalcode), and code is released under the [MIT license](https://opensource.org/licenses/MIT). If you find this content useful, please consider supporting the work by [buying the book](http://shop.oreilly.com/product/0636920034919.do)!*

# %% [markdown]
# <!--NAVIGATION-->
# < [Errors and Debugging](01.06-Errors-and-Debugging.ipynb) | [Contents](Index.ipynb) | [More IPython Resources](01.08-More-IPython-Resources.ipynb) >

# %% [markdown]
# # Profiling and Timing Code

# %% [markdown]
# Timing code: 코드 실행 시간 측정
#
# 목적: 어떤 코드가 얼마나 오래 걸리는지 알고 싶을 때

# %%
# time 모듈 사용

import time

start = time.time()

# 실행할 코드
result = sum([i for i in range(1000000)])

end = time.time()
print(f"실행 시간: {end - start:.4f}초")
# Out:
# 실행 시간: 0.0620초

# %%
# %time sum([i for i in range(1000000)])     # 한 번만 측정
# %timeit sum([i for i in range(1000000)])   # 여러 번 실행해서 평균 측정
# Out:
# CPU times: total: 78.1 ms
# Wall time: 72 ms
# 63.3 ms ± 646 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# 1. Wall Time (벽 시계 시간)
#
# - 실제 경과 시간 (실제 시계 기준)
#
# - 프로그램이 시작해서 끝날 때까지 전체 걸린 시간
#
# - 시스템의 I/O 대기, sleep, 다른 프로세스와의 경쟁 시간도 포함됨

# %% [markdown]
# 2. CPU Time (CPU가 실제로 일한 시간)
#
# - CPU가 이 작업만 실제로 계산한 시간
#
# - I/O 대기, 멀티태스킹 중 대기 시간 등은 제외
#
# - 한 CPU에서만 계산된 순수 연산 시간

# %% [markdown]
# 도널드 커누스(Donald Knuth)는 현대 컴퓨터 과학의 아버지 중 한 명
#
# - 알고리즘 분석의 개척자
# - 알고리즘 분석에 **점근 표기법(Big-O, Ω, Θ)**을 체계화하고 대중화
# - 《The Art of Computer Programming (TAOCP)》 저자
# - “프로그래밍은 예술이다”라는 사고를 퍼뜨린 선구자
# - 튜링상 (1974) – 컴퓨터 과학의 노벨상

# %% [markdown]
# In the process of developing code and creating data processing pipelines, there are often trade-offs you can make between various implementations.
# Early in developing your algorithm, it can be counterproductive to worry about such things. **As Donald Knuth famously quipped, "We should forget about small efficiencies, say about 97% of the time: premature optimization is the root of all evil."**
#
# But once you have your code working, it can be useful to dig into its efficiency a bit.
# Sometimes it's useful to check the execution time of a given command or set of commands; other times it's useful to dig into a multiline process and determine where the bottleneck lies in some complicated series of operations.
# IPython provides access to a wide array of functionality for this kind of timing and profiling of code.
# Here we'll discuss the following IPython magic commands:
# **
# - ``%time``: Time the execution of a single statement
# - ``%timeit``: Time repeated execution of a single statement for more accuracy
# - ``%prun``: Run code with the profiler
# - ``%lprun``: Run code with the line-by-line profiler
# - ``%memit``: Measure the memory use of a single statement
# - ``%mprun``: Run code with the line-by-line memory profiler
# **
# The last four commands are not bundled with IPython–you'll need to get the ``line_profiler`` and ``memory_profiler`` extensions, which we will discuss in the following sections.

# %% [markdown]
# ## Timing Code Snippets: ``%timeit`` and ``%time``
#
# We saw the ``%timeit`` line-magic and ``%%timeit`` cell-magic in the introduction to magic functions in [IPython Magic Commands](01.03-Magic-Commands.ipynb); it can be used to time the repeated execution of snippets of code:

# %%
# %timeit sum(range(100))
# Out:
# 733 ns ± 6.02 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# Note that because this operation is so fast, ``%timeit`` automatically does a large number of repetitions.
# For slower commands, ``%timeit`` will automatically adjust and perform fewer repetitions:

# %%
# %%timeit
total = 0
for i in range(1000):
    for j in range(1000):
        total += i * (-1) ** j
# Out:
# 696 ms ± 40 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# Sometimes repeating an operation is not the best option.
# For example, if we have a list that we'd like to sort, we might be misled by a repeated operation.
# Sorting a pre-sorted list is much faster than sorting an unsorted list, so the repetition will skew the result:

# %%
import random
L = [random.random() for i in range(100000)]
# %timeit L.sort()
# Out:
# 3.69 ms ± 904 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# For this, the ``%time`` magic function may be a better choice. It also is a good choice for longer-running commands, when short, system-related delays are unlikely to affect the result.
# Let's time the sorting of an unsorted and a presorted list:

# %%
import random
L = [random.random() for i in range(100000)]
print("sorting an unsorted list:")
# %time L.sort()
# Out:
# sorting an unsorted list:
# CPU times: user 49 ms, sys: 1.27 ms, total: 50.2 ms
# Wall time: 50.2 ms

# %%
print("sorting an already sorted list:")
# %time L.sort()
# Out:
# sorting an already sorted list:
# CPU times: user 5.49 ms, sys: 97 µs, total: 5.59 ms
# Wall time: 5.54 ms

# %% [markdown]
# Notice how much faster the presorted list is to sort, but notice also how much longer the timing takes with ``%time`` versus ``%timeit``, even for the presorted list!
# This is a result of the fact that ``%timeit`` does some clever things under the hood to prevent system calls from interfering with the timing.
# For example, it prevents cleanup of unused Python objects (known as *garbage collection*) which might otherwise affect the timing.
# For this reason, ``%timeit`` results are usually noticeably faster than ``%time`` results.
#
# For ``%time`` as with ``%timeit``, using the double-percent-sign cell magic syntax allows timing of multiline scripts:

# %%
# %%time
total = 0
for i in range(1000):
    for j in range(1000):
        total += i * (-1) ** j
# Out:
# CPU times: user 871 ms, sys: 17.7 ms, total: 889 ms
# Wall time: 949 ms

# %% [markdown]
# For more information on ``%time`` and ``%timeit``, as well as their available options, use the IPython help functionality (i.e., type ``%time?`` at the IPython prompt).

# %% [markdown]
# 2. Profiling code: 성능 분석 (어디가 느린지)
# - profile: hort description of someone's life work, character => 인간의 옆 모습 파악하기
# - 목적: 어떤 함수/라인이 성능 병목인지 분석

# %%
import cProfile

def slow_function():
    total = 0
    for i in range(10000):
        for j in range(100):
            total += i * j
    return total

cProfile.run('slow_function()')
# Out:
#          4 function calls in 0.042 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.042    0.042    0.042    0.042 792384587.py:3(slow_function)
#         1    0.000    0.000    0.042    0.042 <string>:1(<module>)
#         1    0.000    0.000    0.042    0.042 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %% [markdown]
# ## Profiling Full Scripts: ``%prun``
#
# A program is made of many single statements, and sometimes timing these statements in context is more important than timing them on their own.
# Python contains a built-in code profiler (which you can read about in the Python documentation), but IPython offers a much more convenient way to use this profiler, in the form of the magic function ``%prun``.
#
# By way of example, we'll define a simple function that does some calculations:

# %%
def sum_of_lists(N):
    total = 0
    for i in range(5):
        L = [j ^ (j >> i) for j in range(N)]
        total += sum(L)
    return total

# %% [markdown]
# Now we can call ``%prun`` with a function call to see the profiled results:

# %%
# %prun sum_of_lists(1000000)
# Out:
#          14 function calls in 0.502 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         5    0.394    0.079    0.394    0.079 3519952779.py:4(<listcomp>)
#         5    0.073    0.015    0.073    0.015 {built-in method builtins.sum}
#         1    0.026    0.026    0.493    0.493 3519952779.py:1(sum_of_lists)
#         1    0.009    0.009    0.502    0.502 <string>:1(<module>)
#         1    0.000    0.000    0.502    0.502 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %% [markdown]
# In the notebook, the output is printed to the pager, and looks something like this:
#
# ```
# 14 function calls in 0.714 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         5    0.599    0.120    0.599    0.120 <ipython-input-19>:4(<listcomp>)
#         5    0.064    0.013    0.064    0.013 {built-in method sum}
#         1    0.036    0.036    0.699    0.699 <ipython-input-19>:1(sum_of_lists)
#         1    0.014    0.014    0.714    0.714 <string>:1(<module>)
#         1    0.000    0.000    0.714    0.714 {built-in method exec}
# ```
#
# The result is a table that indicates, in order of total time on each function call, where the execution is spending the most time. In this case, the bulk of execution time is in the list comprehension inside ``sum_of_lists``.
# From here, we could start thinking about what changes we might make to improve the performance in the algorithm.
#
# For more information on ``%prun``, as well as its available options, use the IPython help functionality (i.e., type ``%prun?`` at the IPython prompt).

# %% [markdown]
# ## Line-By-Line Profiling with ``%lprun``
#
# The function-by-function profiling of ``%prun`` is useful, but sometimes it's more convenient to have a line-by-line profile report.
# This is not built into Python or IPython, but there is a ``line_profiler`` package available for installation that can do this.
# Start by using Python's packaging tool, ``pip``, to install the ``line_profiler`` package:
#
# ```
# $ pip install line_profiler
# ```
#
# Next, you can use IPython to load the ``line_profiler`` IPython extension, offered as part of this package:

# %%
# !pip install line_profiler
# Out:
# Requirement already satisfied: line_profiler in c:\code\datascience\.venv\lib\site-packages (4.2.0)

# %%
# %load_ext line_profiler

# %% [markdown]
# Now the ``%lprun`` command will do a line-by-line profiling of any function–in this case, we need to tell it explicitly which functions we're interested in profiling:

# %%
# %lprun -f sum_of_lists sum_of_lists(5000)
# Out:
# Timer unit: 1e-07 s
#
# Total time: 0.0066044 s
# File: C:\Users\user\AppData\Local\Temp\ipykernel_2532\3519952779.py
# Function: sum_of_lists at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def sum_of_lists(N):
#      2         1          5.0      5.0      0.0      total = 0
#      3         6         37.0      6.2      0.1      for i in range(5):
#      4         5      64079.0  12815.8     97.0          L = [j ^ (j >> i) for j in range(N)]
#      5         5       1921.0    384.2      2.9          total += sum(L)
#      6         1          2.0      2.0      0.0      return total

# %% [markdown]
# As before, the notebook sends the result to the pager, but it looks something like this:
#
# ```
# Timer unit: 1e-06 s
#
# Total time: 0.009382 s
# File: <ipython-input-19-fa2be176cc3e>
# Function: sum_of_lists at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def sum_of_lists(N):
#      2         1            2      2.0      0.0      total = 0
#      3         6            8      1.3      0.1      for i in range(5):
#      4         5         9001   1800.2     95.9          L = [j ^ (j >> i) for j in range(N)]
#      5         5          371     74.2      4.0          total += sum(L)
#      6         1            0      0.0      0.0      return total
# ```
#
# The information at the top gives us the key to reading the results: the time is reported in microseconds and we can see where the program is spending the most time.
# At this point, we may be able to use this information to modify aspects of the script and make it perform better for our desired use case.
#
# For more information on ``%lprun``, as well as its available options, use the IPython help functionality (i.e., type ``%lprun?`` at the IPython prompt).

# %% [markdown]
# ## Profiling Memory Use: ``%memit`` and ``%mprun``
#
# Another aspect of profiling is the amount of memory an operation uses.
# This can be evaluated with another IPython extension, the ``memory_profiler``.
# As with the ``line_profiler``, we start by ``pip``-installing the extension:
#
# ```
# $ pip install memory_profiler
# ```
#
# Then we can use IPython to load the extension:

# %%
# %load_ext memory_profiler

# %% [markdown]
# The memory profiler extension contains two useful magic functions: the ``%memit`` magic (which offers a memory-measuring equivalent of ``%timeit``) and the ``%mprun`` function (which offers a memory-measuring equivalent of ``%lprun``).
# The ``%memit`` function can be used rather simply:

# %%
# !pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: numpy==1.23.5 in c:\code\datascience\.venv\lib\site-packages (from -r ../requirements.txt (line 1)) (1.23.5)
# Requirement already satisfied: pandas==1.5.3 in c:\code\datascience\.venv\lib\site-packages (from -r ../requirements.txt (line 2)) (1.5.3)
# Requirement already satisfied: scikit-learn==1.2.2 in c:\code\datascience\.venv\lib\site-packages (from -r ../requirements.txt (line 3)) (1.2.2)
# Requirement already satisfied: matplotlib==3.7.3 in c:\code\datascience\.venv\lib\site-packages (from -r ../requirements.txt (line 4)) (3.7.3)
# Requirement already satisfied: seaborn==0.12.2 in c:\code\datascience\.venv\lib\site-packages (from -r ../requirements.txt (line 5)) (0.12.2)
# Requirement already satisfied: jupyter==1.0.0 in c:\code\datascience\.venv\lib\site-packages (from -r ../requirements.txt (line 6)) (1.0.0)
# Requirement already satisfied: scipy==1.10.1 in c:\code\datascience\.venv\lib\site-packages (from -r ../requirements.txt (line 7)) (1.10.1)
# Requirement already satisfied: line_profiler==4.2.0 in c:\code\datascience\.venv\lib\site-packages (from -r ../requirements.txt (line 8)) (4.2.0)
# Collecting memory_profiler (from -r ../requirements.txt (line 9))
#   Using cached memory_profiler-0.61.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\code\datascience\.venv\lib\site-packages (from pandas==1.5.3->-r ../requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\code\datascience\.venv\lib\site-packages (from pandas==1.5.3->-r ../requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\code\datascience\.venv\lib\site-packages (from scikit-learn==1.2.2->-r ../requirements.txt (line 3)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\code\datascience\.venv\lib\site-packages (from scikit-learn==1.2.2->-r ../requirements.txt (line 3)) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\code\datascience\.venv\lib\site-packages (from matplotlib==3.7.3->-r ../requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\code\datascience\.venv\lib\site-packages (from matplotlib==3.7.3->-r ../requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\code\datascience\.venv\lib\site-packages (from matplotlib==3.7.3->-r ../requirements.txt (line 4)) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\code\datascience\.venv\lib\site-packages (from matplotlib==3.7.3->-r ../requirements.txt (line 4)) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\code\datascience\.venv\lib\site-packages (from matplotlib==3.7.3->-r ../requirements.txt (line 4)) (25.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\code\datascience\.venv\lib\site-packages (from matplotlib==3.7.3->-r ../requirements.txt (line 4)) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\code\datascience\.venv\lib\site-packages (from matplotlib==3.7.3->-r ../requirements.txt (line 4)) (3.2.3)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\code\datascience\.venv\lib\site-packages (from matplotlib==3.7.3->-r ../requirements.txt (line 4)) (6.5.2)
# Requirement already satisfied: notebook in c:\code\datascience\.venv\lib\site-packages (from jupyter==1.0.0->-r ../requirements.txt (line 6)) (7.4.0)
# Requirement already satisfied: qtconsole in c:\code\datascience\.venv\lib\site-packages (from jupyter==1.0.0->-r ../requirements.txt (line 6)) (5.6.1)
# Requirement already satisfied: jupyter-console in c:\code\datascience\.venv\lib\site-packages (from jupyter==1.0.0->-r ../requirements.txt (line 6)) (6.6.3)
# Requirement already satisfied: nbconvert in c:\code\datascience\.venv\lib\site-packages (from jupyter==1.0.0->-r ../requirements.txt (line 6)) (7.16.6)
# Requirement already satisfied: ipykernel in c:\code\datascience\.venv\lib\site-packages (from jupyter==1.0.0->-r ../requirements.txt (line 6)) (6.29.5)
# Requirement already satisfied: ipywidgets in c:\code\datascience\.venv\lib\site-packages (from jupyter==1.0.0->-r ../requirements.txt (line 6)) (8.1.6)
# Requirement already satisfied: psutil in c:\code\datascience\.venv\lib\site-packages (from memory_profiler->-r ../requirements.txt (line 9)) (7.0.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\code\datascience\.venv\lib\site-packages (from importlib-resources>=3.2.0->matplotlib==3.7.3->-r ../requirements.txt (line 4)) (3.21.0)
# Requirement already satisfied: six>=1.5 in c:\code\datascience\.venv\lib\site-packages (from python-dateutil>=2.8.1->pandas==1.5.3->-r ../requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: comm>=0.1.1 in c:\code\datascience\.venv\lib\site-packages (from ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 6)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\code\datascience\.venv\lib\site-packages (from ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 6)) (1.8.14)
# Requirement already satisfied: ipython>=7.23.1 in c:\code\datascience\.venv\lib\site-packages (from ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 6)) (8.18.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\code\datascience\.venv\lib\site-packages (from ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 6)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\code\datascience\.venv\lib\site-packages (from ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 6)) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\code\datascience\.venv\lib\site-packages (from ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 6)) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\code\datascience\.venv\lib\site-packages (from ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 6)) (1.6.0)
# Requirement already satisfied: pyzmq>=24 in c:\code\datascience\.venv\lib\site-packages (from ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 6)) (26.4.0)
# Requirement already satisfied: tornado>=6.1 in c:\code\datascience\.venv\lib\site-packages (from ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 6)) (6.4.2)
# Requirement already satisfied: traitlets>=5.4.0 in c:\code\datascience\.venv\lib\site-packages (from ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 6)) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\code\datascience\.venv\lib\site-packages (from ipywidgets->jupyter==1.0.0->-r ../requirements.txt (line 6)) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.14 in c:\code\datascience\.venv\lib\site-packages (from ipywidgets->jupyter==1.0.0->-r ../requirements.txt (line 6)) (3.0.14)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\code\datascience\.venv\lib\site-packages (from jupyter-console->jupyter==1.0.0->-r ../requirements.txt (line 6)) (3.0.51)
# Requirement already satisfied: pygments in c:\code\datascience\.venv\lib\site-packages (from jupyter-console->jupyter==1.0.0->-r ../requirements.txt (line 6)) (2.19.1)
# Requirement already satisfied: beautifulsoup4 in c:\code\datascience\.venv\lib\site-packages (from nbconvert->jupyter==1.0.0->-r ../requirements.txt (line 6)) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in c:\code\datascience\.venv\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter==1.0.0->-r ../requirements.txt (line 6)) (6.2.0)
# Requirement already satisfied: defusedxml in c:\code\datascience\.venv\lib\site-packages (from nbconvert->jupyter==1.0.0->-r ../requirements.txt (line 6)) (0.7.1)
# Requirement already satisfied: importlib-metadata>=3.6 in c:\code\datascience\.venv\lib\site-packages (from nbconvert->jupyter==1.0.0->-r ../requirements.txt (line 6)) (8.6.1)
# Requirement already satisfied: jinja2>=3.0 in c:\code\datascience\.venv\lib\site-packages (from nbconvert->jupyter==1.0.0->-r ../requirements.txt (line 6)) (3.1.6)
# Requirement already satisfied: jupyterlab-pygments in c:\code\datascience\.venv\lib\site-packages (from nbconvert->jupyter==1.0.0->-r ../requirements.txt (line 6)) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in c:\code\datascience\.venv\lib\site-packages (from nbconvert->jupyter==1.0.0->-r ../requirements.txt (line 6)) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\code\datascience\.venv\lib\site-packages (from nbconvert->jupyter==1.0.0->-r ../requirements.txt (line 6)) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in c:\code\datascience\.venv\lib\site-packages (from nbconvert->jupyter==1.0.0->-r ../requirements.txt (line 6)) (0.10.2)
# Requirement already satisfied: nbformat>=5.7 in c:\code\datascience\.venv\lib\site-packages (from nbconvert->jupyter==1.0.0->-r ../requirements.txt (line 6)) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\code\datascience\.venv\lib\site-packages (from nbconvert->jupyter==1.0.0->-r ../requirements.txt (line 6)) (1.5.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\code\datascience\.venv\lib\site-packages (from notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\code\datascience\.venv\lib\site-packages (from notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (2.27.3)
# Requirement already satisfied: jupyterlab<4.5,>=4.4.0rc0 in c:\code\datascience\.venv\lib\site-packages (from notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (4.4.0)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\code\datascience\.venv\lib\site-packages (from notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (0.2.4)
# Requirement already satisfied: qtpy>=2.4.0 in c:\code\datascience\.venv\lib\site-packages (from qtconsole->jupyter==1.0.0->-r ../requirements.txt (line 6)) (2.4.3)
# Requirement already satisfied: webencodings in c:\code\datascience\.venv\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter==1.0.0->-r ../requirements.txt (line 6)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\code\datascience\.venv\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter==1.0.0->-r ../requirements.txt (line 6)) (1.4.0)
# Requirement already satisfied: decorator in c:\code\datascience\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 6)) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in c:\code\datascience\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 6)) (0.19.2)
# Requirement already satisfied: stack-data in c:\code\datascience\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 6)) (0.6.3)
# Requirement already satisfied: typing-extensions in c:\code\datascience\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 6)) (4.13.2)
# Requirement already satisfied: exceptiongroup in c:\code\datascience\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 6)) (1.2.2)
# Requirement already satisfied: colorama in c:\code\datascience\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 6)) (0.4.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\code\datascience\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 6)) (4.3.7)
# Requirement already satisfied: pywin32>=300 in c:\code\datascience\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 6)) (310)
# Requirement already satisfied: anyio>=3.1.0 in c:\code\datascience\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (4.9.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\code\datascience\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\code\datascience\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\code\datascience\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in c:\code\datascience\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\code\datascience\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (0.21.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\code\datascience\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (2.0.15)
# Requirement already satisfied: send2trash>=1.8.2 in c:\code\datascience\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\code\datascience\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\code\datascience\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\code\datascience\.venv\lib\site-packages (from jupyterlab<4.5,>=4.4.0rc0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (2.0.5)
# Requirement already satisfied: httpx>=0.25.0 in c:\code\datascience\.venv\lib\site-packages (from jupyterlab<4.5,>=4.4.0rc0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\code\datascience\.venv\lib\site-packages (from jupyterlab<4.5,>=4.4.0rc0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (2.2.5)
# Requirement already satisfied: setuptools>=41.1.0 in c:\code\datascience\.venv\lib\site-packages (from jupyterlab<4.5,>=4.4.0rc0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (58.1.0)
# Requirement already satisfied: tomli>=1.2.2 in c:\code\datascience\.venv\lib\site-packages (from jupyterlab<4.5,>=4.4.0rc0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (2.2.1)
# Requirement already satisfied: babel>=2.10 in c:\code\datascience\.venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\code\datascience\.venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (0.12.0)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\code\datascience\.venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (4.23.0)
# Requirement already satisfied: requests>=2.31 in c:\code\datascience\.venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (2.32.3)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\code\datascience\.venv\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter==1.0.0->-r ../requirements.txt (line 6)) (2.21.1)
# Requirement already satisfied: wcwidth in c:\code\datascience\.venv\lib\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter==1.0.0->-r ../requirements.txt (line 6)) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in c:\code\datascience\.venv\lib\site-packages (from beautifulsoup4->nbconvert->jupyter==1.0.0->-r ../requirements.txt (line 6)) (2.7)
# Requirement already satisfied: idna>=2.8 in c:\code\datascience\.venv\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\code\datascience\.venv\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\code\datascience\.venv\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (21.2.0)
# Requirement already satisfied: certifi in c:\code\datascience\.venv\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.5,>=4.4.0rc0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\code\datascience\.venv\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.5,>=4.4.0rc0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (1.0.8)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\code\datascience\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.5,>=4.4.0rc0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\code\datascience\.venv\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 6)) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in c:\code\datascience\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\code\datascience\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\code\datascience\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\code\datascience\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (0.24.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\code\datascience\.venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (3.3.0)
# Requirement already satisfied: pyyaml>=5.3 in c:\code\datascience\.venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (6.0.2)
# Requirement already satisfied: rfc3339-validator in c:\code\datascience\.venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\code\datascience\.venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\code\datascience\.venv\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\code\datascience\.venv\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (2.4.0)
# Requirement already satisfied: executing>=1.2.0 in c:\code\datascience\.venv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 6)) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\code\datascience\.venv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 6)) (3.0.0)
# Requirement already satisfied: pure-eval in c:\code\datascience\.venv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 6)) (0.2.3)
# Requirement already satisfied: fqdn in c:\code\datascience\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (1.5.1)
# Requirement already satisfied: isoduration in c:\code\datascience\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\code\datascience\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (3.0.0)
# Requirement already satisfied: uri-template in c:\code\datascience\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\code\datascience\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\code\datascience\.venv\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (1.17.1)
# Requirement already satisfied: pycparser in c:\code\datascience\.venv\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in c:\code\datascience\.venv\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\code\datascience\.venv\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 6)) (2.9.0.20241206)
# Using cached memory_profiler-0.61.0-py3-none-any.whl (31 kB)
# Installing collected packages: memory_profiler
# Successfully installed memory_profiler-0.61.0

# %%
# !pip install memory_profiler
# Out:
# Requirement already satisfied: memory_profiler in c:\code\datascience\.venv\lib\site-packages (0.61.0)
# Requirement already satisfied: psutil in c:\code\datascience\.venv\lib\site-packages (from memory_profiler) (7.0.0)

# %%
# %memit sum_of_lists(1000000)
# Out:
# UsageError: Line magic function `%memit` not found.

# %% [markdown]
# We see that this function uses about 100 MB of memory.
#
# For a line-by-line description of memory use, we can use the ``%mprun`` magic.
# Unfortunately, this magic works only for functions defined in separate modules rather than the notebook itself, so we'll **start by using the ``%%file`` magic to create a simple module called ``mprun_demo.py``, which contains our ``sum_of_lists`` function**, with one addition that will make our memory profiling results more clear:

# %%
# %%file mprun_demo.py
def sum_of_lists(N):
    total = 0
    for i in range(5):
        L = [j ^ (j >> i) for j in range(N)]
        total += sum(L)
        del L # L 참조 삭제
    return total
# Out:
# Writing mprun_demo.py

# %% [markdown]
# We can now import the new version of this function and run the memory line profiler:

# %%
from mprun_demo import sum_of_lists
# %mprun -f sum_of_lists sum_of_lists(1000000)

# %% [markdown]
# The result, printed to the pager, gives us a summary of the memory use of the function, and looks something like this:
# ```
# Filename: ./mprun_demo.py
#
# Line #    Mem usage    Increment   Line Contents
# ================================================
#      4     71.9 MiB      0.0 MiB           L = [j ^ (j >> i) for j in range(N)]
#
#
# Filename: ./mprun_demo.py
#
# Line #    Mem usage    Increment   Line Contents
# ================================================
#      1     39.0 MiB      0.0 MiB   def sum_of_lists(N):
#      2     39.0 MiB      0.0 MiB       total = 0
#      3     46.5 MiB      7.5 MiB       for i in range(5):
#      4     71.9 MiB     25.4 MiB           L = [j ^ (j >> i) for j in range(N)]
#      5     71.9 MiB      0.0 MiB           total += sum(L)
#      6     46.5 MiB    -25.4 MiB           del L # remove reference to L
#      7     39.1 MiB     -7.4 MiB       return total
# ```
# Here the ``Increment`` column tells us how much each line affects the total memory budget: observe that when we create and delete the list ``L``, we are adding about 25 MB of memory usage.
# This is on top of the background memory usage from the Python interpreter itself.
#
# For more information on ``%memit`` and ``%mprun``, as well as their available options, use the IPython help functionality (i.e., type ``%memit?`` at the IPython prompt).

# %% [markdown]
# <!--NAVIGATION-->
# < [Errors and Debugging](01.06-Errors-and-Debugging.ipynb) | [Contents](Index.ipynb) | [More IPython Resources](01.08-More-IPython-Resources.ipynb) >
